# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('E:\CV\projects\Diabetes detection\Diabetes.csv')
df
# Out:
#       ID  No_Pation Gender  AGE  Urea  Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 0    502      17975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 1    735      34221      M   26   4.5  62    4.9   3.7  1.4  1.1  2.1   0.6
# 2    420      47975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 3    680      87656      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 4    504      34223      M   33   7.1  46    4.9   4.9  1.0  0.8  2.0   0.4
# ..   ...        ...    ...  ...   ...  ..    ...   ...  ...  ...  ...   ...
# 995  200     454317      M   71  11.0  97    7.0   7.5  1.7  1.2  1.8   0.6
# 996  671     876534      M   31   3.0  60   12.3   4.1  2.2  0.7  2.4  15.4
# 997  669      87654      M   30   7.1  81    6.7   4.1  1.1  1.2  2.4   8.1
# 998   99      24004      M   38   5.8  59    6.7   5.3  2.0  1.6  2.9  14.0
# 999  248      24054      M   54   5.0  67    6.9   3.8  1.7  1.1  3.0   0.7
#
#       BMI CLASS
# 0    24.0     N
# 1    23.0     N
# ...

# %%
df.describe()
# Out:
#                 ID     No_Pation          AGE         Urea           Cr  \
# count  1000.000000  1.000000e+03  1000.000000  1000.000000  1000.000000
# mean    340.500000  2.705514e+05    53.528000     5.124743    68.943000
# std     240.397673  3.380758e+06     8.799241     2.935165    59.984747
# min       1.000000  1.230000e+02    20.000000     0.500000     6.000000
# 25%     125.750000  2.406375e+04    51.000000     3.700000    48.000000
# 50%     300.500000  3.439550e+04    55.000000     4.600000    60.000000
# 75%     550.250000  4.538425e+04    59.000000     5.700000    73.000000
# max     800.000000  7.543566e+07    79.000000    38.900000   800.000000
#
#              HbA1c         Chol           TG          HDL          LDL  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      8.281160     4.862820     2.349610     1.204750     2.609790
# std       2.534003     1.301738     1.401176     0.660414     1.115102
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         1000 non-null   int64
#  1   No_Pation  1000 non-null   int64
#  2   Gender     1000 non-null   object
#  3   AGE        1000 non-null   int64
#  4   Urea       1000 non-null   float64
#  5   Cr         1000 non-null   int64
#  6   HbA1c      1000 non-null   float64
#  7   Chol       1000 non-null   float64
#  8   TG         1000 non-null   float64
#  9   HDL        1000 non-null   float64
#  10  LDL        1000 non-null   float64
#  11  VLDL       1000 non-null   float64
#  12  BMI        1000 non-null   float64
#  13  CLASS      1000 non-null   object
# dtypes: float64(8), int64(4), object(2)
# memory usage: 109.5+ KB

# %%
df.isna().sum()
# Out:
# ID           0
# No_Pation    0
# Gender       0
# AGE          0
# Urea         0
# Cr           0
# HbA1c        0
# Chol         0
# TG           0
# HDL          0
# LDL          0
# VLDL         0
# BMI          0
# CLASS        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# convert outliers to nan

# %%
df.boxplot(figsize=(18,14))
# Out:
# <AxesSubplot:>

# %%
def boxplot(df,col):
    plt.title(col)
    sns.boxplot(df[col])
    plt.show()

# %%
boxplot(df,'AGE')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df.loc[(df['AGE']<39) | (df['AGE']>71),'AGE']=np.nan

# %%
boxplot(df,'Urea')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df.loc[(df['Urea']<1.5) | (df['Urea']>8.8),'Urea']=np.nan

# %%
boxplot(df,'HbA1c')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df.loc[(df['HbA1c']<2) | (df['HbA1c']>15),'HbA1c']=np.nan

# %%
boxplot(df,'Cr')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df.loc[(df['Cr']<20) | (df['Cr']>110),'Cr']=np.nan

# %%
boxplot(df,'Chol')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df.loc[(df['Chol']<2) | (df['Chol']>8),'Chol']=np.nan

# %%
boxplot(df,'TG')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df.loc[(df['TG']>5),'TG']=np.nan

# %%
boxplot(df,'HDL')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df.loc[(df['HDL']<0.4) | (df['HDL']>2),'HDL']=np.nan

# %%
boxplot(df,'LDL')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df.loc[(df['LDL']>5.5),'LDL']=np.nan

# %%
boxplot(df,'VLDL')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df.loc[(df['VLDL']>2.5),'VLDL']=np.nan

# %%
boxplot(df,'BMI')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df.loc[(df['BMI']>45),'BMI']=np.nan

# %%
df.isna().sum()
# Out:
# ID            0
# No_Pation     0
# Gender        0
# AGE          98
# Urea         66
# Cr           52
# HbA1c         6
# Chol         25
# TG           55
# HDL          44
# LDL          11
# VLDL         77
# BMI           3
# CLASS         0
# dtype: int64

# %%
df.drop(['ID','No_Pation'],inplace=True,axis=1)

# %%
df.columns
# Out:
# Index(['Gender', 'AGE', 'Urea', 'Cr', 'HbA1c', 'Chol', 'TG', 'HDL', 'LDL',
#        'VLDL', 'BMI', 'CLASS'],
#       dtype='object')

# %% [markdown]
# Dealing with missing values

# %%
from sklearn.impute import KNNImputer

# %%
imputer = KNNImputer()

for col in df.columns[1:-1]:
    df[col]=imputer.fit_transform(df[[col]])

# %%
df.isna().sum()
# Out:
# Gender    0
# AGE       0
# Urea      0
# Cr        0
# HbA1c     0
# Chol      0
# TG        0
# HDL       0
# LDL       0
# VLDL      0
# BMI       0
# CLASS     0
# dtype: int64

# %%
# df=pd.get_dummies(df,columns=['Gender','CLASS'],drop_first=True)
# df

# %% [markdown]
# dealing with non numerical data

# %%
df['Gender'].value_counts()
# Out:
# M    565
# F    434
# f      1
# Name: Gender, dtype: int64

# %%
def convert_gender(col):
    return 0 if (col=='F'or col=='f') else 1

# %%
df['Gender']=df['Gender'].apply(convert_gender)

# %%
df['Gender'].value_counts()
# Out:
# 1    565
# 0    435
# Name: Gender, dtype: int64

# %%
df['CLASS'].value_counts()
# Out:
# Y     840
# N     102
# P      53
# Y       4
# N       1
# Name: CLASS, dtype: int64

# %%
def convert_class(col):
    return 1 if (col=='Y'or col=='P') else 0

# %%
df['CLASS']=df['CLASS'].apply(convert_class)

# %%
df['CLASS'].value_counts()
# Out:
# 1    893
# 0    107
# Name: CLASS, dtype: int64

# %%
df.hist(figsize=(14,18))
# Out:
# array([[<AxesSubplot:title={'center':'Gender'}>,
#         <AxesSubplot:title={'center':'AGE'}>,
#         <AxesSubplot:title={'center':'Urea'}>],
#        [<AxesSubplot:title={'center':'Cr'}>,
#         <AxesSubplot:title={'center':'HbA1c'}>,
#         <AxesSubplot:title={'center':'Chol'}>],
#        [<AxesSubplot:title={'center':'TG'}>,
#         <AxesSubplot:title={'center':'HDL'}>,
#         <AxesSubplot:title={'center':'LDL'}>],
#        [<AxesSubplot:title={'center':'VLDL'}>,
#         <AxesSubplot:title={'center':'BMI'}>,
#         <AxesSubplot:title={'center':'CLASS'}>]], dtype=object)

# %% [markdown]
# no. people who's have diabetes vs haven't according to gender

# %%
sns.countplot(df['Gender'],hue=df['CLASS'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %% [markdown]
# no. men who's haven't diabetes

# %%
df[(df['CLASS']==0)&(df['Gender']==1)]
# Out:
#      Gender        AGE      Urea          Cr      HbA1c      Chol        TG  \
# 1         1  54.940133  4.500000   62.000000   4.900000  3.700000  1.400000
# 4         1  54.940133  7.100000   46.000000   4.900000  4.900000  1.000000
# 7         1  48.000000  4.700000   47.000000   4.000000  2.900000  0.800000
# 8         1  43.000000  2.600000   67.000000   4.000000  3.800000  0.900000
# 15        1  50.000000  5.500000   74.000000   5.000000  3.600000  1.100000
# 23        1  50.000000  4.000000   28.000000   5.300000  4.800000  1.000000
# 26        1  54.940133  4.800000   80.000000   5.500000  5.500000  1.800000
# 27        1  41.000000  4.200000   99.000000   4.000000  2.800000  2.900000
# 28        1  54.940133  2.000000   54.000000   5.400000  3.700000  1.300000
# 31        1  47.000000  4.600000   55.000000   4.300000  4.600000  0.800000
# 32        1  54.940133  3.800000   70.000000   5.000000  3.600000  0.700000
# ...

# %% [markdown]
# no. men who's have diabetes

# %%
df[(df['CLASS']==1)&(df['Gender']==1)]
# Out:
#      Gender        AGE      Urea         Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 103       1  54.940133  3.900000  81.000000    6.0   6.2  3.9  0.8  1.9   1.8
# 104       1  54.940133  3.900000  81.000000    6.0   6.2  3.9  0.8  3.8   1.8
# 105       1  54.940133  3.900000  81.000000    6.0   6.2  3.9  0.8  3.8   1.8
# 106       1  54.940133  3.400000  55.000000    5.7   4.9  1.6  1.0  3.2   0.7
# 107       1  54.940133  3.400000  55.000000    5.7   4.9  1.6  1.0  3.2   0.7
# ..      ...        ...       ...        ...    ...   ...  ...  ...  ...   ...
# 989       1  62.000000  6.300000  82.000000    6.7   5.3  2.0  1.0  3.5   0.9
# 992       1  55.000000  3.100000  39.000000    8.5   5.0  2.5  1.9  2.9   0.7
# 993       1  54.940133  3.500000  61.000000    8.5   4.5  1.9  1.1  2.6   0.8
# 994       1  69.000000  4.586127  59.809072    7.7   4.9  1.9  1.2  3.0   0.7
# 995       1  71.000000  4.586127  97.000000    7.0   7.5  1.7  1.2  1.8   0.6
#
#       BMI  CLASS
# ...

# %% [markdown]
# no. women who's haven't diabetes

# %%
df[(df['CLASS']==0)&(df['Gender']==0)]
# Out:
#      Gender   AGE  Urea          Cr     HbA1c  Chol   TG       HDL  LDL  VLDL  \
# 0         0  50.0   4.7   46.000000  4.900000   4.2  0.9  1.109571  1.4   0.5
# 2         0  50.0   4.7   46.000000  4.900000   4.2  0.9  1.109571  1.4   0.5
# 3         0  50.0   4.7   46.000000  4.900000   4.2  0.9  1.109571  1.4   0.5
# 5         0  45.0   2.3   24.000000  4.000000   2.9  1.0  1.000000  1.5   0.4
# 6         0  50.0   2.0   50.000000  4.000000   3.6  1.3  0.900000  2.1   0.6
# ..      ...   ...   ...         ...       ...   ...  ...       ...  ...   ...
# 94        0  44.0   7.3   59.809072  4.300000   5.2  1.9  1.109571  3.0   0.7
# 96        0  54.0   6.3  106.000000  5.600000   4.3  2.0  1.300000  2.2   0.9
# 97        0  50.0   3.3   70.000000  4.900000   3.7  0.9  1.200000  2.7   0.6
# 100       0  59.0   4.7   58.000000  4.100000   4.5  1.8  1.800000  1.8   1.3
# 101       0  57.0   4.6   97.000000  8.295433   3.2  1.3  0.900000  3.0   1.1
#
#       BMI  CLASS
# ...

# %% [markdown]
# no. women who's have diabetes

# %%
df[(df['CLASS']==1)&(df['Gender']==0)]
# Out:
#      Gender        AGE      Urea         Cr  HbA1c  Chol        TG   HDL  \
# 108       0  43.000000  2.100000  55.000000    5.7   4.7  2.122339  0.90
# 115       0  49.000000  3.300000  44.000000    6.0   5.6  1.900000  0.75
# 117       0  49.000000  3.300000  44.000000    6.0   5.6  1.900000  0.75
# 120       0  49.000000  3.300000  44.000000    6.0   5.6  1.900000  0.75
# 121       0  39.000000  3.000000  38.000000    6.4   4.7  1.300000  1.10
# ..      ...        ...       ...        ...    ...   ...       ...   ...
# 982       0  54.000000  5.000000  88.000000    6.8   5.1  2.100000  1.10
# 984       0  60.000000  5.000000  70.000000    8.1   5.2  3.300000  1.40
# 985       0  54.940133  4.586127  59.809072    8.6   4.2  1.600000  0.90
# 990       0  57.000000  4.100000  70.000000    9.3   5.3  3.300000  1.00
# 991       0  55.000000  4.100000  34.000000   13.9   5.4  1.600000  1.60
#
#       LDL      VLDL   BMI  CLASS
# 108  1.70  2.400000  25.0      1
# ...

# %%
df[(df['CLASS']==1)&(df['AGE']<df['AGE'].mean())]
# Out:
#      Gender   AGE  Urea    Cr  HbA1c  Chol        TG       HDL  LDL  VLDL  \
# 108       0  43.0   2.1  55.0    5.7   4.7  2.122339  0.900000  1.7   2.4
# 109       1  42.0   5.4  53.0    5.8   5.9  3.700000  1.300000  3.1   1.7
# 110       1  47.0   4.1  87.0    6.2   3.7  1.800000  1.000000  2.0   0.8
# 111       1  50.0   4.3  59.0    6.1   4.0  3.000000  1.000000  1.8   1.3
# 112       1  49.0   5.0  74.0    6.2   2.0  0.800000  0.600000  1.0   0.4
# ..      ...   ...   ...   ...    ...   ...       ...       ...  ...   ...
# 973       1  50.0   4.8  70.0    8.0   5.2  2.700000  1.400000  2.7   1.2
# 975       1  48.0   4.1  79.0   11.3   6.1  2.122339  1.100000  2.1   0.7
# 978       1  52.0   5.1  70.0    7.0   7.5  1.700000  1.200000  1.8   0.6
# 980       1  51.0   5.5  83.0    9.4   6.4  2.300000  1.109571  3.2   1.0
# 982       0  54.0   5.0  88.0    6.8   5.1  2.100000  1.100000  3.0   1.0
#
#       BMI  CLASS
# 108  25.0      1
# 109  23.0      1
# 110  23.0      1
# ...

# %%
df[(df['CLASS']==1)&(df['AGE']>df['AGE'].mean())]
# Out:
#      Gender        AGE      Urea         Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 103       1  54.940133  3.900000  81.000000    6.0   6.2  3.9  0.8  1.9   1.8
# 104       1  54.940133  3.900000  81.000000    6.0   6.2  3.9  0.8  3.8   1.8
# 105       1  54.940133  3.900000  81.000000    6.0   6.2  3.9  0.8  3.8   1.8
# 106       1  54.940133  3.400000  55.000000    5.7   4.9  1.6  1.0  3.2   0.7
# 107       1  54.940133  3.400000  55.000000    5.7   4.9  1.6  1.0  3.2   0.7
# ..      ...        ...       ...        ...    ...   ...  ...  ...  ...   ...
# 991       0  55.000000  4.100000  34.000000   13.9   5.4  1.6  1.6  3.1   0.7
# 992       1  55.000000  3.100000  39.000000    8.5   5.0  2.5  1.9  2.9   0.7
# 993       1  54.940133  3.500000  61.000000    8.5   4.5  1.9  1.1  2.6   0.8
# 994       1  69.000000  4.586127  59.809072    7.7   4.9  1.9  1.2  3.0   0.7
# 995       1  71.000000  4.586127  97.000000    7.0   7.5  1.7  1.2  1.8   0.6
#
#       BMI  CLASS
# ...

# %% [markdown]
# no. people who's have diabetes vs haven't according to mean of the age

# %%
sns.countplot(df['CLASS'],hue=df['AGE']>df['AGE'].mean())
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='CLASS', ylabel='count'>

# %%
plt.figure(figsize=(14,8))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
df.drop(['LDL','HDL','Cr'],inplace=True,axis=1)

# %%
X=df.drop(['CLASS'],axis=1)
y=df['CLASS']

# %% [markdown]
# try to make the data balanced using over sampling

# %%
df['CLASS'].value_counts()
# Out:
# 1    893
# 0    107
# Name: CLASS, dtype: int64

# %%
from imblearn.over_sampling import SMOTE
oversample = SMOTE()
X, y = oversample.fit_resample(X, y)

# %%
y.value_counts()
# Out:
# 0    893
# 1    893
# Name: CLASS, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=32)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
x_train=scaler.fit_transform(X_train)
x_test=scaler.transform(X_test)

# %%
# !pip install lazypredict

# %%
# from lazypredict.Supervised import LazyClassifier

# %%
# clf=LazyClassifier(verbose=0,ignore_wranging=True,custem_metric=None)
# models,prediction=clf.fit(X_train, X_test, y_train, y_test)
# models

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score

# %%
models = {
    "LR": LogisticRegression(),
    "KNN": KNeighborsClassifier(),
    "SVC": SVC(),
    "DT": DecisionTreeClassifier(),
    "RF": RandomForestClassifier(),
    "Naive Bayes": GaussianNB()
}

# %%
for name, model in models.items():
    print(f'Training Model {name} \n--------------')
    model.fit(x_train, y_train)
    y_pred = model.predict(x_test)
    print(f'Training Accuracy: {accuracy_score(y_train, model.predict(x_train))}')
    print(f'Testing Accuracy: {accuracy_score(y_test, y_pred)}')
    print(f'Testing Confusion Matrix: \n{confusion_matrix(y_test, y_pred)}')
    print(f'Testing Recall: {recall_score(y_test, y_pred)}')    
    print(f'Testing Precesion: {precision_score(y_test, y_pred)}')
    print('-'*30)
# Out:
# Training Model LR
# --------------
# Training Accuracy: 0.9367588932806324
# Testing Accuracy: 0.9552238805970149
# Testing Confusion Matrix:
# [[139   4]
#  [  8 117]]
# Testing Recall: 0.936
# Testing Precesion: 0.9669421487603306
# ------------------------------
# Training Model KNN
# --------------
# Training Accuracy: 0.9710144927536232
# Testing Accuracy: 0.9664179104477612
# Testing Confusion Matrix:
# [[143   0]
#  [  9 116]]
# Testing Recall: 0.928
# Testing Precesion: 1.0
# ------------------------------
# Training Model SVC
# --------------
# Training Accuracy: 0.9650856389986825
# Testing Accuracy: 0.9738805970149254
# Testing Confusion Matrix:
# [[139   4]
#  [  3 122]]
# Testing Recall: 0.976
# Testing Precesion: 0.9682539682539683
# ------------------------------
# Training Model DT
# --------------
# Training Accuracy: 0.9980237154150198
# Testing Accuracy: 0.9925373134328358
# Testing Confusion Matrix:
# [[143   0]
#  [  2 123]]
# Testing Recall: 0.984
# ...

# %%
import joblib

# %%
joblib.dump(scaler, 'signs_scaler.h5')
joblib.dump(model, 'signs_model.h5')
# Out:
# ['signs_model.h5']
